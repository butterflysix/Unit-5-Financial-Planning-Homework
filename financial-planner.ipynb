# %% [markdown]
# # Unit 5 - Financial Planning

# %%
# Initial imports
import os
import requests
import pandas as pd
import json
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
from MCForecastTools import MCSimulation

# %matplotlib inline

# %%
# Load .env enviroment variables
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Part 1 - Personal Finance Planner

# %% [markdown]
# ### Collect Crypto Prices Using the `requests` Library

# %%
# Set current amount of crypto assets
crypto_shares_data = {
    "crypto": [1.2, 5.3]
}

cryptocurrencies = ["BTC", "ETH"]

crypto_df = pd.DataFrame(crypto_shares_data, index=cryptocurrencies) 
    
crypto_df
# Out:
#      crypto
# BTC     1.2
# ETH     5.3

# %%
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

# %%
alpaca = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")

# %%
# Crypto API URLs
btc_url = "https://api.alternative.me/v2/ticker/Bitcoin/?convert=CAD"
eth_url = "https://api.alternative.me/v2/ticker/Ethereum/?convert=CAD"

# %%
btc_response_data = requests.get(btc_url).json()
print(json.dumps(btc_response_data, indent=4))
# Out:
# {
#     "data": {
#         "1": {
#             "id": 1,
#             "name": "Bitcoin",
#             "symbol": "BTC",
#             "website_slug": "bitcoin",
#             "rank": 1,
#             "circulating_supply": 18613212,
#             "total_supply": 18613212,
#             "max_supply": 21000000,
#             "quotes": {
#                 "USD": {
#                     "price": 33367.0,
#                     "volume_24h": 51095928576,
#                     "market_cap": 621067633435,
#                     "percentage_change_1h": 0.156547782179825,
#                     "percentage_change_24h": 10.3123851389239,
#                     "percentage_change_7d": -6.23943309326767,
#                     "percent_change_1h": 0.156547782179825,
#                     "percent_change_24h": 10.3123851389239,
#                     "percent_change_7d": -6.23943309326767
#                 },
#                 "CAD": {
#                     "price": 42786.5041,
#                     "volume_24h": 65520309213.0048,
#                     "market_cap": 796395026353.701,
#                     "percent_change_1h": 0.156547782179825,
#                     "percent_change_24h": 10.3123851389239,
#                     "percent_change_7d": -6.23943309326767
#                 }
#             },
#             "last_updated": 1611877666
#         }
#     },
#     "metadata": {
#         "timestamp": 1611877666,
#         "num_cryptocurrencies": 1371,
#         "error": null
#     }
# }

# %%
eth_response_data = requests.get(eth_url).json()
print(json.dumps(eth_response_data, indent=4))
# Out:
# {
#     "data": {
#         "1027": {
#             "id": 1027,
#             "name": "Ethereum",
#             "symbol": "ETH",
#             "website_slug": "ethereum",
#             "rank": 2,
#             "circulating_supply": 114443634,
#             "total_supply": 114443634,
#             "max_supply": 0,
#             "quotes": {
#                 "USD": {
#                     "price": 1335.83,
#                     "volume_24h": 32837487504,
#                     "market_cap": 153925615367,
#                     "percentage_change_1h": -1.17478163605614,
#                     "percentage_change_24h": 7.3746481183362,
#                     "percentage_change_7d": -3.60952891284406,
#                     "percent_change_1h": -1.17478163605614,
#                     "percent_change_24h": 7.3746481183362,
#                     "percent_change_7d": -3.60952891284406
#                 },
#                 "CAD": {
#                     "price": 1712.934809,
#                     "volume_24h": 42107510226.3792,
#                     "market_cap": 197378816585.104,
#                     "percent_change_1h": -1.17478163605614,
#                     "percent_change_24h": 7.3746481183362,
#                     "percent_change_7d": -3.60952891284406
#                 }
#             },
#             "last_updated": 1611877747
#         }
#     },
#     "metadata": {
#         "timestamp": 1611877747,
#         "num_cryptocurrencies": 1371,
#         "error": null
#     }
# }

# %%
btc_price = btc_response_data["data"]["1"]["quotes"]["USD"]["price"]
btc_price
# Out:
# 33367.0

# %%
eth_price = eth_response_data["data"]["1027"]["quotes"]["USD"]["price"]
eth_price
# Out:
# 1335.83

# %%
my_btc = crypto_df.loc['BTC']['crypto']
my_eth = crypto_df.loc['ETH']['crypto']

# %%
# Fetch current BTC price
print(btc_price)

# # Fetch current ETH price
print(eth_price)

# Compute current value of my crpto
my_btc_value = btc_price * crypto_df.loc["BTC"]["crypto"]
my_eth_value = eth_price * crypto_df.loc["ETH"]["crypto"]

# Print current crypto wallet balance
print(f"The current value of your {crypto_df.iloc[0]['crypto']} BTC is ${my_btc_value:0.2f}")
print(f"The current value of your {crypto_df.iloc[1]['crypto']} ETH is ${my_eth_value:0.2f}")
# Out:
# 33367.0
# 1335.83
# The current value of your 1.2 BTC is $40040.40
# The current value of your 5.3 ETH is $7079.90

# %%
crypto_total = my_btc_value + my_eth_value
crypto_total
# Out:
# 47120.299

# %% [markdown]
# ### Collect Investments Data Using Alpaca: `SPY` (stocks) and `AGG` (bonds)

# %%
# Current amount of shares
shares_data = {
    "shares": [200, 50]
}

# Set the tickers
tickers = ["AGG", "SPY"]

# Create the shares DataFrame
df_shares = pd.DataFrame(shares_data, index=tickers)

# Display shares data
df_shares
# Out:
#      shares
# AGG     200
# SPY      50

# %%
# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

# %%
# Format current date as ISO format
today = pd.Timestamp("2021-01-25", tz="America/New_York").isoformat()

# Set the tickers
tickers = ["AGG", "SPY"]

# Set timeframe to '1D' for Alpaca API
timeframe = "1D"

# Get current closing prices for SPY and AGG
df_portfolio = alpaca.get_barset(
    tickers,
    timeframe,
    start = today,
    end = today
).df

# Preview DataFrame
df_portfolio
# Out:
#                               AGG                                      SPY  \
#                              open    high     low   close   volume    open
# time
# 2021-01-25 00:00:00-05:00  117.39  117.56  117.36  117.54  3977366  383.67
#
#
#                              high     low  close    volume
# time
# 2021-01-25 00:00:00-05:00  384.77  378.46  384.4  61090775

# %%
# Pick AGG and SPY close prices
agg_close_price = float(df_portfolio["AGG"]["close"])
spy_close_price = float(df_portfolio["SPY"]["close"])

# Print AGG and SPY close prices
print(f"Current AGG closing price: ${agg_close_price}")
print(f"Current SPY closing price: ${spy_close_price}")
# Out:
# Current AGG closing price: $117.54
# Current SPY closing price: $384.4

# %%
my_agg = df_shares.loc['AGG']['shares']
my_spy = df_shares.loc['SPY']['shares']

# %%
# Compute the current value of shares
my_agg_value = agg_close_price * df_shares.loc["AGG"]["shares"]
my_spy_value = spy_close_price * df_shares.loc["SPY"]["shares"]

# Print current value of share
print(f"The current value of your {my_spy} SPY shares is ${my_spy_value:0.2f}")
print(f"The current value of your {my_agg} AGG shares is ${my_agg_value:0.2f}")
# Out:
# The current value of your 50 SPY shares is $19220.00
# The current value of your 200 AGG shares is $23508.00

# %%
shares_total = my_agg_value + my_spy_value
shares_total
# Out:
# 42728.0

# %% [markdown]
# ### Savings Health Analysis

# %%
# Set monthly household income
monthly_income = 12000

# Create savings DataFrame
assets = [shares_total, crypto_total]
index_labels = ['crypto','shares']
df_savings = pd.DataFrame(assets,index=index_labels)

df_savings.columns = ['amount']

# Display savings DataFrame
display(df_savings)
# Out:
#            amount
# crypto  42728.000
# shares  47120.299

# %%
# Plot savings pie chart
df_savings.plot.pie(title='Composition of Personal Savings',y='amount',figsize=(10,5))

my_labels = 'crypto','shares'

# %%
# Set ideal emergency fund
emergency_fund = monthly_income * 3

# Calculate total amount of savings
total_savings = crypto_total + shares_total

print(f"Total savings is ${total_savings:0.2f}")

# Validate saving health
if total_savings > emergency_fund:
    print('Congratulations, you have enough money in the fund.')
    
elif total_savings == emergency_fund:
    print('Congratulations, you have reached your goal.')

elif total_savings < emergency_fund:
    print(f'Oops! You have ${emergency_fund-total_savings} USD less.')
# Out:
# Total savings is $89848.30
# Congratulations, you have enough money in the fund.

# %% [markdown]
# ## Part 2 - Retirement Planning
#
# ### Monte Carlo Simulation

# %%
 # Set Alpaca API key and secret
# alpaca_api_key = os.getenv("ALPACA_API_KEY")
# alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

api = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version = "v2"
)

# %%
# Set start and end dates of five years back from today.
# Sample results may vary from the solution based on the time frame chosen
timeframe = "1D"
start_date = pd.Timestamp('2015-08-07', tz='America/New_York').isoformat()
end_date = pd.Timestamp('2020-08-07', tz='America/New_York').isoformat()

# %%
# Get 5 years' worth of historical data for SPY and AGG
tickers = ["SPY","AGG"]

df_stock_data = api.get_barset(
    tickers,
    timeframe,
    start=start_date,
    end=end_date
).df

# Display sample data
df_stock_data.head()
# Out:
#                               AGG                                         SPY  \
#                              open      high      low   close   volume    open
# time
# 2015-08-07 00:00:00-04:00  109.14  109.2750  109.035  109.21  2041167  208.16
# 2015-08-10 00:00:00-04:00  109.15  109.1700  108.920  109.06  1149778  209.28
# 2015-08-11 00:00:00-04:00  109.42  109.5765  109.284  109.42  1420907  208.98
# 2015-08-12 00:00:00-04:00  109.55  109.7100  109.350  109.36  1468979  207.11
# 2015-08-13 00:00:00-04:00  109.36  109.3651  109.110  109.15  1465173  208.73
#
#
#                              high     low   close     volume
# time
# 2015-08-07 00:00:00-04:00  208.34  206.87  207.93   87669782
# 2015-08-10 00:00:00-04:00  210.67  209.28  210.58   66755890
# 2015-08-11 00:00:00-04:00  209.47  207.76  208.63   88424557
# 2015-08-12 00:00:00-04:00  209.14  205.36  208.89  136171450
# 2015-08-13 00:00:00-04:00  209.55  208.01  208.63   77197796

# %%
# Configuring a Monte Carlo simulation to forecast 30 years cumulative returns
MC_thirtyyear = MCSimulation(
    portfolio_data = df_stock_data,
    weights = [.60,.40],
    num_simulation = 500,
    num_trading_days = 252*30
)

# %%
# Printing the simulation input data
MC
# ...        ...       ...       ...       ...        ...       ...       ...
# 7531  6.178610  2.318131  4.340369  4.754509  11.729377  1.535688  4.327712
# 7532  6.145377  2.307253  4.326647  4.724814  11.693745  1.546251  4.317773
# 7533  6.122395  2.298064  4.300337  4.694446  11.674167  1.536164  4.320844
# 7534  6.157967  2.302084  4.251580  4.715679  11.584520  1.528207  4.313766
# 7535  6.163454  2.289935  4.269851  4.741536  11.536034  1.524553  4.343915
# 7536  6.129745  2.296737  4.258486  4.764652  11.564500  1.523775  4.336575
# 7537  6.130128  2.298522  4.274855  4.778356  11.623903  1.519712  4.313172
# 7538  6.124505  2.295870  4.281297  4.786936  11.623395  1.514328  4.302285
# 7539  6.123776  2.316223  4.245380  4.789901  11.788924  1.505429  4.282268
# 7540  6.138416  2.310171  4.225001  4.777584  11.859439  1.510365  4.273057
# 7541  6.144977  2.311106  4.253295  4.782983  11.876505  1.514293  4.267760
# 7542  6.165456  2.317068  4.269570  4.736880  11.830199  1.504735  4.285976
# 7543  6.185375  2.336782  4.234695  4.790731  11.862946  1.506766  4.304389
# 7544  6.211684  2.357043  4.279806  4.754714  11.967697  1.511769  4.312591
# 7545  6.149776  2.362681  4.271134  4.750718  11.977512  1.513085  4.320580
# 7546  6.162510  2.371430  4.262351  4.768403  12.082045  1.514823  4.309748
# 7547  6.211752  2.373557  4.278554  4.789830  12.011331  1.517622  4.319408
# 7548  6.198983  2.387908  4.295663  4.823422  11.982193  1.513900  4.284797
# 7549  6.176995  2.365882  4.317009  4.815091  11.993790  1.518524  4.258805
# 7550  6.183816  2.362265  4.315451  4.764604  11.939234  1.520969  4.280273
# 7551  6.187555  2.366863  4.325188  4.787185  12.010636  1.513164  4.253448
# 7552  6.113051  2.364459  4.348659  4.801432  12.010590  1.514833  4.256433
# 7553  6.083297  2.353593  4.349891  4.819921  12.065427  1.509869  4.237523
# 7554  6.115644  2.347457  4.368128  4.862982  12.065352  1.512297  4.228378
# 7555  6.084684  2.357034  4.362966  4.866101  12.073677  1.517386  4.237999
# 7556  6.080288  2.356031  4.384865  4.832792  12.066221  1.516596  4.200247
# 7557  6.069182  2.353171  4.370847  4.858105  12.032211  1.516621  4.150634
# 7558  6.051022  2.335159  4.362824  4.878238  12.011691  1.510472  4.147265
# 7559  6.043289  2.334810  4.360484  4.892971  11.967929  1.495629  4.173282
# 7560  6.044761  2.310102  4.369761  4.921742  11.916185  1.490010  4.147591
#
# [7561 rows x 500 columns]

# %%
# Plot simulation outcomes
line_plot = MC_thirtyyear.plot_simulation()

# %%
# Plot probability distribution and confidence intervals
dist_plot = MC_thirtyyear.plot_distribution()

# %% [markdown]
# ### Retirement Analysis

# %%
# Fetch summary statistics from the Monte Carlo simulation results
summary_stats= MC_thirtyyear.summarize_cumulative_return()

# Print summary statistics
print(summary_stats)
# Out:
# count           500.000000
# mean              5.555216
# std               2.608055
# min               0.984652
# 25%               3.714945
# 50%               4.953203
# 75%               6.910710
# max              20.470403
# 95% CI Lower      2.203292
# 95% CI Upper     11.955200
# Name: 7560, dtype: float64

# %% [markdown]
# ### Calculate the expected portfolio return at the 95% lower and upper confidence intervals based on a `$20,000` initial investment.

# %%
# Set initial investment
initial_investment = 20000

# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $20,000
ci_lower = round(summary_stats[8]*20000,2)
ci_upper = round(summary_stats[9]*20000,2)

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
      f" over the next 30 years will end within in the range of"
      f" ${ci_lower} and ${ci_upper}")
# Out:
# There is a 95% chance that an initial investment of $20000 in the portfolio over the next 30 years will end within in the range of $44065.83 and $239103.99

# %% [markdown]
# ### Calculate the expected portfolio return at the `95%` lower and upper confidence intervals based on a `50%` increase in the initial investment.

# %%
# Set initial investment
initial_investment = 20000 * 1.5

# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $30,000
ci_lower = round(summary_stats[8]*10000,2)
ci_upper = round(summary_stats[9]*10000,2)

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
      f" over the next 30 years will end within in the range of"
      f" ${ci_lower} and ${ci_upper}")
# Out:
# There is a 95% chance that an initial investment of $30000.0 in the portfolio over the next 30 years will end within in the range of $22032.92 and $119552.0

# %% [markdown]
# ## Optional Challenge - Early Retirement
#
#
# ### Five Years Retirement Option

# %%
# Configuring a Monte Carlo simulation to forecast 5 years cumulative returns
# YOUR CODE HERE!

# %%
# Running a Monte Carlo simulation to forecast 5 years cumulative returns
# YOUR CODE HERE!

# %%
# Plot simulation outcomes
# YOUR CODE HERE!

# %%
# Plot probability distribution and confidence intervals
# YOUR CODE HERE!

# %%
# Fetch summary statistics from the Monte Carlo simulation results
# YOUR CODE HERE!

# Print summary statistics
# YOUR CODE HERE!

# %%
# Set initial investment
# YOUR CODE HERE!

# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $60,000
# YOUR CODE HERE!

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
      f" over the next 5 years will end within in the range of"
      f" ${ci_lower_five} and ${ci_upper_five}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-d56b774f48d0> in <module>
#       6
#       7 # Print results
# ----> 8 print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
#       9       f" over the next 5 years will end within in the range of"
#      10       f" ${ci_lower_five} and ${ci_upper_five}")
#
# NameError: name 'ci_lower_five' is not defined

# %% [markdown]
# ### Ten Years Retirement Option

# %%
# Configuring a Monte Carlo simulation to forecast 10 years cumulative returns
# YOUR CODE HERE!

# %%
# Running a Monte Carlo simulation to forecast 10 years cumulative returns
# YOUR CODE HERE!

# %%
# Plot simulation outcomes
# YOUR CODE HERE!

# %%
# Plot probability distribution and confidence intervals
# YOUR CODE HERE!

# %%
# Fetch summary statistics from the Monte Carlo simulation results
# YOUR CODE HERE!

# Print summary statistics
# YOUR CODE HERE!

# %%
# Set initial investment
# YOUR CODE HERE!

# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $60,000
# YOUR CODE HERE!

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
      f" over the next 10 years will end within in the range of"
      f" ${ci_lower_ten} and ${ci_upper_ten}")
